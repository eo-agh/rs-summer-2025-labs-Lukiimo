# %% [markdown]
# # Exercise: Create a Python Package for Cloud-Free Mosaics

# %% [markdown]
# In this exercise, your goal is to:
#
# 1. Create a function that generates a cloud-free mosaic using Sentinel-2 data and Google Earth Engine.
# 2. Turn this function into a reusable Python package.
# 3. Organize your code using proper Python package structure.
# 4. Install your package locally in editable mode.
# 5. Test your package using a script or notebook.

# %% [markdown]
# ## Step 1: Write the Function
# Create a function called `create_cloud_free_mosaic(aoi, start_date, end_date)` that:
# - Filters Sentinel-2 imagery by date and area,
# - Applies a cloud mask using the `QA60` band,
# - Returns a cloud-free median composite.

# %% [markdown]
# ## Step 2: Create the Package Structure
# Use the following folder layout:
#
# ```
# geoapps/
# ├── geoapps/
# │   ├── __init__.py
# │   └── lab03/
# │       ├── __init__.py
# │       └── cloud_mosaic.py  # <- your function goes here
# ├── pyproject.toml
# └── README.md
# ```

# %% [markdown]
# ## Step 3: Create `pyproject.toml`
# Use the following template:
#
# ```toml
# [build-system]
# requires = ["setuptools", "wheel"]
# build-backend = "setuptools.build_meta"
#
# [project]
# name = "geoapps"
# version = "0.1.0"
# requires-python = ">=3.10"
# description = "EO utilities for cloud-free mosaics"
# authors = [
#   { name = "Your Name", email = "your@email.com" }
# ]
#
# [tool.setuptools.packages.find]
# where = ["."]
# exclude = ["tests", "notebooks"]
# ```

# %% [markdown]
# ## Step 4: Install Your Package
# From the root of your project (where `pyproject.toml` is located), run:
#
# ```bash
# pip install -e .
# ```

# %% [markdown]
# ## Step 5: Test the Package
# Create a test script or notebook and try importing your function like this:
#
# ```python
# from geoapps.lab03.cloud_mosaic import create_cloud_free_mosaic
#
# import ee
# ee.Initialize(project='your-ee-project-id')
#
# aoi = ee.Geometry.Rectangle([19.8, 50.0, 20.0, 50.2])
# mosaic = create_cloud_free_mosaic(aoi, '2023-06-01', '2023-07-01')
# print(mosaic.getInfo())
# ```

# %%
pip install -e .
# Out:
# Obtaining file:///C:/Users/lukas/Documents/RemoteSensing/rs-summer-2025-labs-Lukiimo
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: geoapps
#   Building editable for geoapps (pyproject.toml): started
#   Building editable for geoapps (pyproject.toml): finished with status 'done'
#   Created wheel for geoapps: filename=geoapps-0.1.0-0.editable-py3-none-any.whl size=2881 sha256=3ffbefc3eb017ca1cfd49c27e944022a527d5422e13c873c602961de3f91cbf8
#   Stored in directory: C:\Users\lukas\AppData\Local\Temp\pip-ephem-wheel-cache-0if3_en6\wheels\76\3b\28\ca879b4c7e464aec54654ea96f705e151ba105937ab8df79db
# Successfully built geoapps
# Installing collected packages: geoapps
#   Attempting uninstall: geoapps
#     Found existing installation: geoapps 0.1.0
#     Uninstalling geoapps-0.1.0:
#       Successfully uninstalled geoapps-0.1.0
# Successfully installed geoapps-0.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from geoapps.lab03 import cloud_mosaic

cloud_mosaic.display_cloud_map()
cloud_mosaic.display_cloud_free_mosaic()
# Out:
# c:\Users\lukas\miniconda3\envs\eo_lab\lib\site-packages\ee\deprecation.py:207: DeprecationWarning:
#
# Attention required for COPERNICUS/S2_SR! You are using a deprecated asset.
# To make sure your code keeps working, please update it.
# Learn more: https://developers.google.com/earth-engine/datasets/catalog/COPERNICUS_S2_SR
#
#   warnings.warn(warning, category=DeprecationWarning)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d7d57dc580f5611b8fcc25439bfc625 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d7d57dc580f5611b8fcc25439bfc625&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d7d57dc580f5611b8fcc25439bfc625 = L.map(
#                 &quot;map_4d7d57dc580f5611b8fcc25439bfc625&quot;,
#                 {
#                     center: [50.09997336373202, 19.899999999999498],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b1d3968df6dabb8aefa4e101565d2309 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b1d3968df6dabb8aefa4e101565d2309.addTo(map_4d7d57dc580f5611b8fcc25439bfc625);
#
#
#             var tile_layer_e49f9fa498e6d1eae5e474d20f1023c2 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/lukiim/maps/ce6f8122ae940183be1618cc96cf238e-b1f89b8efeb6d817de7c7eca7af2d0e6/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e49f9fa498e6d1eae5e474d20f1023c2.addTo(map_4d7d57dc580f5611b8fcc25439bfc625);
#
#
#             var tile_layer_5da872e7d941bfd31f93b2a83a4680cc = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/lukiim/maps/3e7c46869d6d814fb6ab8c60d71f7d73-78402ee4408b197cd0a5ee50bb7722bd/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             var tile_layer_43736697b74891185a507dedb10a6d35 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/lukiim/maps/d325ac3810ca674d080327b28aa85f86-6bcd6075c5d65a5f31a07f9d97bac437/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             var tile_layer_5199711340123fac0f4f9ff234bc94be = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/lukiim/maps/2bbc63a915a685c54989f31f395b3764-46b3e27350233c0eb01b1dd63d0e0ed9/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             var tile_layer_7d2abd14bedcf85666551c62101e79d3 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/lukiim/maps/b01b63e8c7391faad09dcf42c4ece7ab-f015ba91d54b62f013f93b5ee43116f8/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             var tile_layer_9e7de89b803796a6b2c5a5f8f033411f = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/lukiim/maps/ab47c4c3311d5c42df6ce895a6b01fa4-f038e90f9125854e77637bbcc4c3f83f/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             var tile_layer_07d3002eaaf1273e931ff02a562e9d68 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/lukiim/maps/bceb20ac6fb91c4f27b73aefd3202169-f5d404666a641b929ed1e184d7f2256e/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1bdce8d3a7ad9f9590f4fbb8366dd583 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1bdce8d3a7ad9f9590f4fbb8366dd583&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1bdce8d3a7ad9f9590f4fbb8366dd583 = L.map(
#                 &quot;map_1bdce8d3a7ad9f9590f4fbb8366dd583&quot;,
#                 {
#                     center: [50.09997336373202, 19.899999999999498],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e89e39d533e4ad811db8307ed1751bf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0e89e39d533e4ad811db8307ed1751bf.addTo(map_1bdce8d3a7ad9f9590f4fbb8366dd583);
#
#
#             var tile_layer_3860b0d205d4dadb92e51c910c9a69db = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/lukiim/maps/3929eb04cb3405947f9f645bb219be82-d762fcd720ea9dfdb117787a7a0feaf0/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3860b0d205d4dadb92e51c910c9a69db.addTo(map_1bdce8d3a7ad9f9590f4fbb8366dd583);
#
#
#             var layer_control_9f4312408b994a07a152612b8d522cf4_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_0e89e39d533e4ad811db8307ed1751bf,
#                 },
#                 overlays :  {
#                     &quot;S2 cloud-free mosaic&quot; : tile_layer_3860b0d205d4dadb92e51c910c9a69db,
#                 },
#             };
#             let layer_control_9f4312408b994a07a152612b8d522cf4 = L.control.layers(
#                 layer_control_9f4312408b994a07a152612b8d522cf4_layers.base_layers,
#                 layer_control_9f4312408b994a07a152612b8d522cf4_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_1bdce8d3a7ad9f9590f4fbb8366dd583);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Step 6: Bonus – Add a Demo Notebook
# Create a notebook in a separate `notebooks/` folder where you import and visualize the result using `geemap`:
#
# ```python
# import geemap
# Map = geemap.Map(center=[50.1, 19.9], zoom=10)
# Map.addLayer(mosaic, {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 3000}, 'Mosaic')
# Map
# ```
